# %%
import torch
import torch.nn as nn
import dgl.function as fn
import torch.nn.functional as F
import dgl
import time
from dgl import DGLGraph
from dgl.data import citation_graph as citegrh
import networkx as nx
import numpy as np
from dgl.nn.pytorch import edge_softmax, GATConv


class GATLayer(nn.Module):
    def __init__(self, g, in_dim , out_dim):
        super(GATLayer, self).__init__()
        self.g = g
        self.fc = nn.Linear(in_dim, out_dim, bias=False)
        self.attn_fc = nn.Linear(2*out_dim, 1, bias=False)
        self.reset_parameters()

    def reset_parameters(self):
        gain = nn.init.calculate_gain('relu')
        nn.init.xavier_normal_(self.fc.weight, gain=gain)
        nn.init.xavier_normal_(self.attn_fc.weight, gain=gain)

    def edge_attention(self, edges):
        z2 = torch.cat([edges.src['z'], edges.dst['z']], dim=1)
        a = self.attn_fc(z2)
        return {'e': F.leaky_relu(a)}

    def message_func(self,edges):
        return {'z': edges.src['z'], 'e': edges.data['e']}

    def reduce_func(self, nodes):
        alpha = F.softmax(nodes.mailbox['e'], dim=1) # 归一化每一条入边的注意力系数
        h = torch.sum(alpha * nodes.mailbox['z'], dim=1)
        return {'h':h}

    def forward(self, h):
        z = self.fc(h)
        self.g.ndata['z'] = z # 每个节点的特征
        self.g.apply_edges(self.edge_attention) # 为每一条边获得其注意力系数
        self.g.update_all(self.message_func, self.reduce_func)
        return self.g.ndata.pop('h')

class MultiHeadGATLayer(nn.Module):
    def __init__(self, g, in_dim , out_dim , num_heads=1, merge='cat'):
        super(MultiHeadGATLayer, self).__init__()
        self.heads = nn.ModuleList()
        for i in range(num_heads):
            self.heads.append(GATLayer(g, in_dim, out_dim))
        self.merge = merge


    def forward(self, h):
        head_out = [attn_head(h) for attn_head in self.heads]
        if self.merge=='cat':
            return torch.cat(head_out, dim=1)
        else:
            return torch.mean(torch.stack(head_out))

class GAT(nn.Module):
    def __init__(self, g, in_dim, hidden_dim , out_dim, num_heads):
        super(GAT, self).__init__()
        self.layer1 = MultiHeadGATLayer(g , in_dim, hidden_dim, num_heads)
        self.layer2 = MultiHeadGATLayer(g, hidden_dim*num_heads, out_dim, 1)

    def forward(self, h):
        h = self.layer1(h)
        h = F.elu(h)
        h = self.layer2(h)
        return h
# Out:
# Using backend: pytorch

# %%
import networkx as nx
def load_cora_data():
    data = citegrh.load_cora()
    features = torch.FloatTensor(data.features)
    labels = torch.LongTensor(data.labels)
    train_mask = torch.BoolTensor(data.train_mask)
    test_mask = torch.BoolTensor(data.test_mask)
    g = data.graph
    # add self loop
    # g.remove_edges_from(nx.selfloop_edges(g))
    g = dgl.from_networkx(g)
    g.add_edges(g.nodes(), g.nodes())
    return g, features, labels, train_mask, test_mask

g, features, labels, train_mask,test_mask = load_cora_data()

net = GAT(g, features.size()[1], hidden_dim=16, out_dim=7, num_heads=2)

optimizer = torch.optim.Adam(net.parameters(), lr = 1e-3)

dur = []

print(net)
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# GAT(
#   (layer1): MultiHeadGATLayer(
#     (heads): ModuleList(
#       (0): GATLayer(
#         (fc): Linear(in_features=1433, out_features=16, bias=False)
#         (attn_fc): Linear(in_features=32, out_features=1, bias=False)
#       )
#       (1): GATLayer(
#         (fc): Linear(in_features=1433, out_features=16, bias=False)
#         (attn_fc): Linear(in_features=32, out_features=1, bias=False)
#       )
#     )
#   )
#   (layer2): MultiHeadGATLayer(
#     (heads): ModuleList(
#       (0): GATLayer(
#         (fc): Linear(in_features=32, out_features=7, bias=False)
#         (attn_fc): Linear(in_features=14, out_features=1, bias=False)
#       )
#     )
#   )
# )
# /root/anaconda3/envs/size_env_1.0/lib/python3.7/site-packages/dgl/data/utils.py:285: UserWarning: Property dataset.feat will be deprecated, please use g.ndata['feat'] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /root/anaconda3/envs/size_env_1.0/lib/python3.7/site-packages/dgl/data/utils.py:285: UserWarning: Property dataset.label will be deprecated, please use g.ndata['label'] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /root/anaconda3/envs/size_env_1.0/lib/python3.7/site-packages/dgl/data/utils.py:285: UserWarning: Property dataset.train_mask will be deprecated, please use g.ndata['train_mask'] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /root/anaconda3/envs/size_env_1.0/lib/python3.7/site-packages/dgl/data/utils.py:285: UserWarning: Property dataset.test_mask will be deprecated, please use g.ndata['test_mask'] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /root/anaconda3/envs/size_env_1.0/lib/python3.7/site-packages/dgl/data/utils.py:285: UserWarning: Property dataset.graph will be deprecated, please use dataset[0] instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))

# %%
# 模型评估
def evaluate(model, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        _, indices = torch.max(logits, dim=1)
        correct = torch.sum(indices == labels)
        return correct.item() * 1.0 / len(labels)

# %%
for epoch in range(50):
    if epoch >=3:
        t0 = time.time()
    
    net.train()
    logits = net(features)
    logp = F.log_softmax(logits, 1)
    loss = F.nll_loss(logp[test_mask], labels[test_mask])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if epoch >=3:
        dur.append(time.time() - t0)

    # print("Epoch {:05d} | Loss {:.4f} | Time(s) {:.4f}".format(epoch, loss.item(), np.mean(dur)))
    acc = evaluate(net, g, features, labels, test_mask)
    print("Epoch {:05d} | Loss {:.4f} | Test Acc {:.4f} | Time(s) {:.4f}".format(epoch, loss.item(), acc, np.mean(dur)))


embedding_weights = net(features).detach().numpy()  ## 得到所有节点的embedding。

print(embedding_weights[0])
# Out:
# Epoch 00000 | Loss 0.1870 | Test Acc 0.9570 | Time(s) 0.1098
# Epoch 00001 | Loss 0.1864 | Test Acc 0.9570 | Time(s) 0.1098
# Epoch 00002 | Loss 0.1858 | Test Acc 0.9580 | Time(s) 0.1098
# Epoch 00003 | Loss 0.1852 | Test Acc 0.9590 | Time(s) 0.1098
# Epoch 00004 | Loss 0.1846 | Test Acc 0.9600 | Time(s) 0.1098
# Epoch 00005 | Loss 0.1840 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00006 | Loss 0.1834 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00007 | Loss 0.1828 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00008 | Loss 0.1822 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00009 | Loss 0.1816 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00010 | Loss 0.1810 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00011 | Loss 0.1804 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00012 | Loss 0.1798 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00013 | Loss 0.1792 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00014 | Loss 0.1786 | Test Acc 0.9610 | Time(s) 0.1098
# Epoch 00015 | Loss 0.1780 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00016 | Loss 0.1775 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00017 | Loss 0.1769 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00018 | Loss 0.1763 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00019 | Loss 0.1757 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00020 | Loss 0.1752 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00021 | Loss 0.1746 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00022 | Loss 0.1741 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00023 | Loss 0.1735 | Test Acc 0.9620 | Time(s) 0.1098
# Epoch 00024 | Loss 0.1729 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00025 | Loss 0.1724 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00026 | Loss 0.1718 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00027 | Loss 0.1713 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00028 | Loss 0.1708 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00029 | Loss 0.1702 | Test Acc 0.9620 | Time(s) 0.1097
# Epoch 00030 | Loss 0.1697 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00031 | Loss 0.1691 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00032 | Loss 0.1686 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00033 | Loss 0.1681 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00034 | Loss 0.1676 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00035 | Loss 0.1670 | Test Acc 0.9630 | Time(s) 0.1097
# Epoch 00036 | Loss 0.1665 | Test Acc 0.9640 | Time(s) 0.1097
# Epoch 00037 | Loss 0.1660 | Test Acc 0.9640 | Time(s) 0.1097
# Epoch 00038 | Loss 0.1655 | Test Acc 0.9640 | Time(s) 0.1097
# Epoch 00039 | Loss 0.1650 | Test Acc 0.9640 | Time(s) 0.1097
# Epoch 00040 | Loss 0.1644 | Test Acc 0.9650 | Time(s) 0.1097
# Epoch 00041 | Loss 0.1639 | Test Acc 0.9650 | Time(s) 0.1097
# Epoch 00042 | Loss 0.1634 | Test Acc 0.9650 | Time(s) 0.1097
# Epoch 00043 | Loss 0.1629 | Test Acc 0.9650 | Time(s) 0.1097
# Epoch 00044 | Loss 0.1624 | Test Acc 0.9650 | Time(s) 0.1097
# Epoch 00045 | Loss 0.1619 | Test Acc 0.9660 | Time(s) 0.1097
# Epoch 00046 | Loss 0.1614 | Test Acc 0.9660 | Time(s) 0.1097
# Epoch 00047 | Loss 0.1609 | Test Acc 0.9660 | Time(s) 0.1096
# Epoch 00048 | Loss 0.1604 | Test Acc 0.9660 | Time(s) 0.1096
# Epoch 00049 | Loss 0.1600 | Test Acc 0.9660 | Time(s) 0.1096
# [-1.6410836  -0.9433991  -0.7992736   3.568378   -0.40978384 -1.5227715
#  -1.0281743 ]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def plot_embeddings(embeddings, X, Y):
    print(Y)
    emb_list = []
    for k in X:
        emb_list.append(embeddings[k])
    emb_list = np.array(emb_list)

    model = TSNE(n_components=2) ### 降维
    node_pos = model.fit_transform(emb_list)

    color_idx = {}
    for i in range(len(X)):
        color_idx.setdefault(Y[i], [])
        color_idx[Y[i]].append(i)

    for c, idx in color_idx.items():
        plt.scatter(node_pos[idx, 0], node_pos[idx, 1], label=c)
    plt.legend()
    plt.show()
plot_embeddings(embedding_weights, np.arange(features.size()[0]), labels.numpy())
# Out:
# [3 4 4 ... 3 3 3]
